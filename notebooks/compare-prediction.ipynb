# %%
with open("/Users/pat/Downloads/pred_text_Scheme_B.txt", "r") as fh:
    scheme_b_jin = fh.readlines()

# %%
with open("../best-test-lstm-schemeB-with-both-do.txt", "r") as fh:
    pat_scheme_b = fh.readlines()

# %%
r = (490, 500)
for i, (jin, pat) in enumerate(zip(scheme_b_jin, pat_scheme_b)):
    
    if r[0] <= i <= r[1]:
        print("------")
        print("🤪JIN:")
        print(jin)
        print("😎PAT:")
        print(pat)
# Out:
# ------
# 🤪JIN:
# "|ดิฉัน|ไม่|รังเกียจ|หรอก|ค่ะ|"| |หล่อน|บอก|เขา|ตาม|ตรง|
#
# 😎PAT:
# "|ดิฉัน|ไม่|รังเกียจ|หรอก|ค่ะ|"| |หล่อน|บอก|เขา|ตาม|ตรง
#
# ------
# 🤪JIN:
# "|เพราะ|เหตุ|ใด|?|"| |เขา|ถาม|สั้น| |ๆ| |แต่|ประกาย|ตา|ที่|มอง|มา|ประหลาด|ล้ำ|จน|หญิง|สาว|หัวใจ|สะท้าน| |ดัง|นั้น| |หล่อน|จึง|อ้อมแอ้ม|ตอบ|เขา|ว่า|
#
# 😎PAT:
# "|เพราะ|เหตุ|ใด|?|"| |เขา|ถาม|สั้น| |ๆ| |แต่|ประกาย|ตา|ที่|มอง|มา|ประหลาด|ล้ำ|จน|หญิง|สาว|หัวใจ|สะท้าน| |ดัง|นั้น| |หล่อน|จึง|อ้อม|แอ้ม|ตอบ|เขา|ว่า
#
# ------
# 🤪JIN:
# "|เพราะ|คุณ|หมอมรุต|มี|พระคุณ|ต่อ|ดิฉัน|ค่ะ|"|
#
# 😎PAT:
# "|เพราะ|คุณหมอม|รุต|มี|พระคุณ|ต่อ|ดิฉัน|ค่ะ|"
#
# ------
# 🤪JIN:
# "| |เท่า|นั้น| |เอง|...|?|"| |เสียง|ของ|มรุต|เหมือน|น้อยใจ| |นางสาวฤทธิ์ณรงค์|จึง|ไถล|ก้ม|หน้า|หมุน|แก้ว|น้ำ|ที่|วาง|อยู่|บน|โต๊ะ|นั้น|เล่น| |นายศิวะเวชม์|จึง|ถือ|โอกาส|นี้|พินิจ|ดู|หญิง|สาว|เต็มตา| |ดัง|นั้น| |พอ|แพร|เงย|หน้า|ขึ้น|หล่อน| |จึง|พบ|ว่า|มรุต|กำลัง|มอง|หล่อน|อยู่| |รอย|ยิ้ม|จาง| |ๆ| |ปรากฏ|ขึ้น|ที่|ริมฝีปาก|ของ|ชาย|หนุ่ม|ก่อน|ที่|เขา|จะ|พูด|ว่า|
#
# 😎PAT:
# ...

# %%
import ssg

# %%
ssg.syllable_tokenize("นางคลารา มอร์แกน")
# Out:
# ['นาง', 'คลา', 'รา ', 'มอร์', 'แกน']
